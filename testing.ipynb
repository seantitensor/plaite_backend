# %%
# Out:
# ---------------------------------------------------------------------------
# InvalidOperationError                     Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data.get_filtered_recipes(query={'ingredients': 'carrot'})
#
# File ~/Documents/plaite-app/plaite_backend/src/plaite/data/loader.py:388, in get_filtered_recipes(query)
#     340 """
#     341 Get recipes with optional filtering.
#     342
#    (...)    385 get_batch_of_recipes : Get limited number of recipes
#     386 """
#     387 if query:
# --> 388     return filter_recipes(query)
#     389 return load_recipes()
#
# File ~/Documents/plaite-app/plaite_backend/src/plaite/data/loader.py:151, in filter_recipes(filters)
#     148 if filter_exprs:
#     149     query = query.filter(*filter_exprs)
# --> 151 return query.collect()
#
# ...
